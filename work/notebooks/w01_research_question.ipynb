# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/harishgurjar08/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("""
Lane: Search Ranking & Content Performance

I chose this lane because I want to understand which page characteristics are associated with declining search performance. The goal is to identify pages that may need attention first using observable data instead of guessing.
""")
# Out:
# Lane: Search Ranking & Content Performance
#
# I chose this lane because I want to understand which page characteristics are associated with declining search performance. The goal is to identify pages that may need attention first using observable data instead of guessing.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""
Decision: Which pages should be reviewed first for declining search performance?

Action: The SEO/content team reviews the highest-priority pages and updates or improves them.

Cost of a wrong call: Time may be spent improving pages that do not need attention while important declining pages are missed.
""")
# Out:
# Decision: Which pages should be reviewed first for declining search performance?
#
# Action: The SEO/content team reviews the highest-priority pages and updates or improves them.
#
# Cost of a wrong call: Time may be spent improving pages that do not need attention while important declining pages are missed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import subprocess
import pandas as pd

REPO = "flyrank-ml-internship-starter"

if not os.path.exists(REPO):
    subprocess.run([
        "git", "clone", "--depth", "1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter.git"
    ], check=True)

df = pd.read_csv(f"{REPO}/data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Rows: 30000
# Columns: 44
# Average CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
This work can identify observed patterns in the dataset and help prioritize pages for review.
It supports decision-making based on available data.
It does not prove causation, predict Google's algorithm, or guarantee ranking improvements.
""")
# Out:
# This work can identify observed patterns in the dataset and help prioritize pages for review.
# It supports decision-making based on available data.
# It does not prove causation, predict Google's algorithm, or guarantee ranking improvements.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
