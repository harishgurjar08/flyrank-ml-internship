# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/harishgurjar08/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
print("""
1. One Row:
One row represents one webpage for one reporting period.

2. Table:
The content_refresh_anonymized dataset.

3. Time Window:
March 2026 (mid-panel month).

4. Prediction Target:
Whether a page is likely to show declining search performance.

5. Deliberately Excluded:
Future information and label-derived values are excluded to prevent data leakage.
""")
# Out:
# 1. One Row:
# One row represents one webpage for one reporting period.
#
# 2. Table:
# The content_refresh_anonymized dataset.
#
# 3. Time Window:
# March 2026 (mid-panel month).
#
# 4. Prediction Target:
# Whether a page is likely to show declining search performance.
#
# 5. Deliberately Excluded:
# Future information and label-derived values are excluded to prevent data leakage.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
import os
import subprocess
import pandas as pd

REPO="flyrank-ml-internship-starter"

if not os.path.exists(REPO):
    subprocess.run([
        "git","clone","--depth","1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter.git"
    ],check=True)

df=pd.read_csv(f"{REPO}/data/raw/content_refresh_anonymized.csv")

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
print("Verification Query 1")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nVerification Query 2")
print("Missing Values:")
print(df.isnull().sum().head(10))

print("\nVerification Query 3")
print("Date Window:")
if "date" in df.columns:
    print(df["date"].min())
    print(df["date"].max())
else:
    print("Date column not available in starter dataset.")
# Out:
# Verification Query 1
# Rows: 30000
# Columns: 44
#
# Verification Query 2
# Missing Values:
# content_id              0
# client_id               0
# search_volume        2468
# competition          2468
# competition_level    2610
# cpc                  2468
# content_type            0
# main_intent          2374
# word_count           7699
# char_count           7699
# dtype: int64
#
# Verification Query 3
# Date Window:
# Date column not available in starter dataset.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
print("""
Data Limitations

1. Dataset is anonymized.
2. External ranking factors are not available.
3. Future information cannot be used.
4. Results are observational only.
5. This dataset cannot prove causation.
""")
# Out:
# Data Limitations
#
# 1. Dataset is anonymized.
# 2. External ranking factors are not available.
# 3. Future information cannot be used.
# 4. Results are observational only.
# 5. This dataset cannot prove causation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
