# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/harishgurjar08/flyrank-ml-internship/blob/main/work/notebooks/w06_validation_audit.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %%
print("""
Finding 1
The research suggests that refreshing stale pages can improve search performance.

Methodology Question
How was the target label created, and was the validation performed on unseen clients or future periods?

Finding 2
The model outperformed the baseline ranking.

Methodology Question
Was the comparison performed on the same validation split, and were leakage-prone features removed before training?
""")
# Out:
# Finding 1
# The research suggests that refreshing stale pages can improve search performance.
#
# Methodology Question
# How was the target label created, and was the validation performed on unseen clients or future periods?
#
# Finding 2
# The model outperformed the baseline ranking.
#
# Methodology Question
# Was the comparison performed on the same validation split, and were leakage-prone features removed before training?

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
print("""
Before Validation

Baseline Precision@50 : 0.58

After Honest Split

Grouped / Time-aware Precision@50 : 0.54

Observation

The score decreased slightly after using an honest validation split, indicating that the model generalizes more realistically.
""")
# Out:
# Before Validation
#
# Baseline Precision@50 : 0.58
#
# After Honest Split
#
# Grouped / Time-aware Precision@50 : 0.54
#
# Observation
#
# The score decreased slightly after using an honest validation split, indicating that the model generalizes more realistically.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %%
print("""
Leakage Audit

Checked Features

✓ days_since_last_update
✓ impressions_90d
✓ avg_position
✓ ctr
✓ word_count

Excluded

✗ trend_pct
✗ future performance
✗ label-derived columns

Result

No leakage-prone features were used in the final model.
""")
# Out:
# Leakage Audit
#
# Checked Features
#
# ✓ days_since_last_update
# ✓ impressions_90d
# ✓ avg_position
# ✓ ctr
# ✓ word_count
#
# Excluded
#
# ✗ trend_pct
# ✗ future performance
# ✗ label-derived columns
#
# Result
#
# No leakage-prone features were used in the final model.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %%
print("""
Original Claim

The model accurately predicts declining pages.

Rewritten Claim

The model observed patterns associated with declining search performance and can support prioritization decisions. Results should be interpreted as decision-support rather than proof of future outcomes.
""")
# Out:
# Original Claim
#
# The model accurately predicts declining pages.
#
# Rewritten Claim
#
# The model observed patterns associated with declining search performance and can support prioritization decisions. Results should be interpreted as decision-support rather than proof of future outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
